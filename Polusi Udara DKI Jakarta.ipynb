# %% [markdown]
# # 1. Collecting Data

# %%
import numpy as np
import pandas as pd

df1 = pd.read_csv('pencemaran udara.csv')
df1
# Out:
#         tanggal                           stasiun pm10 so2  co  o3 no2  max  \
# 0    2020-01-01                DKI1 (Bunderan HI)   30  20  10  32   9   32
# 1    2020-01-02                DKI1 (Bunderan HI)   27  22  12  29   8   29
# 2    2020-01-03                DKI1 (Bunderan HI)   39  22  14  32  10   39
# 3    2020-01-04                DKI1 (Bunderan HI)   34  22  14  38  10   38
# 4    2020-01-05                DKI1 (Bunderan HI)   35  22  12  31   9   35
# ..          ...                               ...  ...  ..  ..  ..  ..  ...
# 150  2020-01-27  DKI5 (Kebon Jeruk) Jakarta Barat   31  14  17  58   7   58
# 151  2020-01-28  DKI5 (Kebon Jeruk) Jakarta Barat   65  16  35  65   9   65
# 152  2020-01-29  DKI5 (Kebon Jeruk) Jakarta Barat   56  17  25  73   5   73
# 153  2020-01-30  DKI5 (Kebon Jeruk) Jakarta Barat   27  19  16  61   8   61
# 154  2020-01-31  DKI5 (Kebon Jeruk) Jakarta Barat   46  16  24  44   7   46
#
#     critical categori
# 0         O3     BAIK
# ...

# %%
import numpy as np
import pandas as pd

df2 = pd.read_csv('pencemaran udara 2.csv')
df2
# Out:
#         tanggal                           stasiun pm10  so2  co   o3 no2  max  \
# 0    2020-02-01                DKI1 (Bunderan HI)   29    8  19   27  14   29
# 1    2020-02-02                DKI1 (Bunderan HI)   37   10  24   28  12   37
# 2    2020-02-03                DKI1 (Bunderan HI)   39    8  37   19  15   39
# 3    2020-02-04                DKI1 (Bunderan HI)   24    8  29   21  14   29
# 4    2020-02-05                DKI1 (Bunderan HI)   43    8  30   29  12   43
# ..          ...                               ...  ...  ...  ..  ...  ..  ...
# 140  2020-02-25  DKI5 (Kebon Jeruk) Jakarta Barat   20   14  15   83   5   83
# 141  2020-02-26  DKI5 (Kebon Jeruk) Jakarta Barat   40   18  17   52   7   52
# 142  2020-02-27  DKI5 (Kebon Jeruk) Jakarta Barat   27  ---  22   50  10   50
# 143  2020-02-28  DKI5 (Kebon Jeruk) Jakarta Barat   18  ---  17  121  11  121
# 144  2020-02-29  DKI5 (Kebon Jeruk) Jakarta Barat   40  ---  39  144  13  144
#
#     critical     categori
# ...

# %%
import numpy as np
import pandas as pd

df3 = pd.read_csv('pencemaran udara 3.csv')
df3
# Out:
#         tanggal stasiun pm10 so2   co  o3  no2  max critical     categori
# 0    2020-03-01      45    5  13   28   8   45  1.0     PM10         BAIK
# 1    2020-03-02      34    5  15   32  10   34  1.0     PM10         BAIK
# 2    2020-03-03      59    5  23   29  14   59  1.0     PM10       SEDANG
# 3    2020-03-04      56    7  19   55  16   56  1.0     PM10       SEDANG
# 4    2020-03-05      35    6  16   30  13   35  1.0     PM10         BAIK
# ..          ...     ...  ...  ..  ...  ..  ...  ...      ...          ...
# 150  2020-03-27      40  ---   6  117   5  117  4.0       O3  TIDAK SEHAT
# 151  2020-03-28      58   11  12  124   6  124  4.0       O3  TIDAK SEHAT
# 152  2020-03-29      65   14  11   91   7   91  4.0       O3       SEDANG
# 153  2020-03-30      53    9  10   76   5   76  4.0       O3       SEDANG
# 154  2020-03-31      47   11  14   96   6   96  4.0       O3       SEDANG
#
# [155 rows x 10 columns]

# %%
import numpy as np
import pandas as pd

df4 = pd.read_csv('pencemaran udara 4.csv')
df4
# Out:
#         tanggal                           stasiun pm10 so2  co   o3 no2  max  \
# 0    2020-04-01                DKI1 (Bunderan HI)   38   6  12   67  10   67
# 1    2020-04-02                DKI1 (Bunderan HI)   32   4   6   33   7   33
# 2    2020-04-03                DKI1 (Bunderan HI)   30   5   4   33   5   33
# 3    2020-04-04                DKI1 (Bunderan HI)   42   6   8   47   7   47
# 4    2020-04-05                DKI1 (Bunderan HI)   50   4   6   63   8   63
# ..          ...                               ...  ...  ..  ..  ...  ..  ...
# 145  2020-04-26  DKI5 (Kebon Jeruk) Jakarta Barat   61   8  16  101  10  101
# 146  2020-04-27  DKI5 (Kebon Jeruk) Jakarta Barat   34   6   6  131   8  131
# 147  2020-04-28  DKI5 (Kebon Jeruk) Jakarta Barat   46   6  14   82   9   82
# 148  2020-04-29  DKI5 (Kebon Jeruk) Jakarta Barat   51   8  16   85  10   85
# 149  2020-04-30  DKI5 (Kebon Jeruk) Jakarta Barat   69   7  36   76  17   76
#
#     critical     categori
# ...

# %%
import numpy as np
import pandas as pd

df5 = pd.read_csv('pencemaran udara 5.csv')
df5
# Out:
#         tanggal                           stasiun pm10 so2   co   o3 no2  max  \
# 0    2020-05-01                DKI1 (Bunderan HI)   47   2  ---   38  10   47
# 1    2020-05-02                DKI1 (Bunderan HI)   32   2   12   29   9   32
# 2    2020-05-03                DKI1 (Bunderan HI)   52   5   11   35   9   52
# 3    2020-05-04                DKI1 (Bunderan HI)   50   4    4   30   8   50
# 4    2020-05-05                DKI1 (Bunderan HI)   51   7    7   34   9   51
# ..          ...                               ...  ...  ..  ...  ...  ..  ...
# 150  2020-05-27  DKI5 (Kebon Jeruk) Jakarta Barat   24   8    5   74   3   74
# 151  2020-05-28  DKI5 (Kebon Jeruk) Jakarta Barat   32   9    7  136   7  136
# 152  2020-05-29  DKI5 (Kebon Jeruk) Jakarta Barat   48  12    9  134   8  134
# 153  2020-05-30  DKI5 (Kebon Jeruk) Jakarta Barat   48  11   18   73   9   73
# 154  2020-05-31  DKI5 (Kebon Jeruk) Jakarta Barat   52   9   17   66   9   66
#
#     critical     categori
# ...

# %%
import numpy as np
import pandas as pd

df6 = pd.read_csv('pencemaran udara 6.csv')
df6
# Out:
#         tanggal                           stasiun pm10 so2  co  o3 no2  max  \
# 0    2020-06-01                DKI1 (Bunderan HI)   50  14  10  45   9   50
# 1    2020-06-02                DKI1 (Bunderan HI)   44  14   7  37   8   44
# 2    2020-06-03                DKI1 (Bunderan HI)   41  14   4  31   8   41
# 3    2020-06-04                DKI1 (Bunderan HI)   45  18   4  28   8   45
# 4    2020-06-05                DKI1 (Bunderan HI)   56  18   6  60  12   60
# ..          ...                               ...  ...  ..  ..  ..  ..  ...
# 145  2020-06-26  DKI5 (Kebon Jeruk) Jakarta Barat   71  14  23  97  13   97
# 146  2020-06-27  DKI5 (Kebon Jeruk) Jakarta Barat   55  14  11  64   7   64
# 147  2020-06-28  DKI5 (Kebon Jeruk) Jakarta Barat   58  16  10  71   7   71
# 148  2020-06-29  DKI5 (Kebon Jeruk) Jakarta Barat   56  15  10  90  11   90
# 149  2020-06-30  DKI5 (Kebon Jeruk) Jakarta Barat   67  15  16  86  10   86
#
#     critical categori
# 0       PM10     BAIK
# ...

# %%
import pandas as pd

# Gabungkan semua data
data_gabung = pd.concat([df1, df2, df3, df4, df5, df6], axis=0)

data_gabung
# Out:
#         tanggal                           stasiun pm10 so2  co  o3 no2   max  \
# 0    2020-01-01                DKI1 (Bunderan HI)   30  20  10  32   9  32.0
# 1    2020-01-02                DKI1 (Bunderan HI)   27  22  12  29   8  29.0
# 2    2020-01-03                DKI1 (Bunderan HI)   39  22  14  32  10  39.0
# 3    2020-01-04                DKI1 (Bunderan HI)   34  22  14  38  10  38.0
# 4    2020-01-05                DKI1 (Bunderan HI)   35  22  12  31   9  35.0
# ..          ...                               ...  ...  ..  ..  ..  ..   ...
# 145  2020-06-26  DKI5 (Kebon Jeruk) Jakarta Barat   71  14  23  97  13  97.0
# 146  2020-06-27  DKI5 (Kebon Jeruk) Jakarta Barat   55  14  11  64   7  64.0
# 147  2020-06-28  DKI5 (Kebon Jeruk) Jakarta Barat   58  16  10  71   7  71.0
# 148  2020-06-29  DKI5 (Kebon Jeruk) Jakarta Barat   56  15  10  90  11  90.0
# 149  2020-06-30  DKI5 (Kebon Jeruk) Jakarta Barat   67  15  16  86  10  86.0
#
#     critical categori
# ...

# %%
# Mengambil subset data dengan stasiun DKI5
df = data_gabung[data_gabung['stasiun'] == 'DKI5 (Kebon Jeruk) Jakarta Barat']
df = df.replace('---', np.nan)

# Menampilkan subset data
df
# Out:
#         tanggal                           stasiun pm10 so2  co   o3  no2  \
# 124  2020-01-01  DKI5 (Kebon Jeruk) Jakarta Barat   35  13  18   46  NaN
# 125  2020-01-02  DKI5 (Kebon Jeruk) Jakarta Barat   22  15  24  102    7
# 126  2020-01-03  DKI5 (Kebon Jeruk) Jakarta Barat   44  17  21   63    7
# 127  2020-01-04  DKI5 (Kebon Jeruk) Jakarta Barat   40  18  19   85    9
# 128  2020-01-05  DKI5 (Kebon Jeruk) Jakarta Barat   37  21  18   62    5
# ..          ...                               ...  ...  ..  ..  ...  ...
# 145  2020-06-26  DKI5 (Kebon Jeruk) Jakarta Barat   71  14  23   97   13
# 146  2020-06-27  DKI5 (Kebon Jeruk) Jakarta Barat   55  14  11   64    7
# 147  2020-06-28  DKI5 (Kebon Jeruk) Jakarta Barat   58  16  10   71    7
# 148  2020-06-29  DKI5 (Kebon Jeruk) Jakarta Barat   56  15  10   90   11
# 149  2020-06-30  DKI5 (Kebon Jeruk) Jakarta Barat   67  15  16   86   10
#
#        max critical     categori
# 124   46.0       O3         BAIK
# ...

# %% [markdown]
# # 2. Processing Data

# %%
import pandas as pd

# Mendeteksi data duplikat
duplikat = df.duplicated()

# Menampilkan jumlah data yang duplikat
print("Jumlah data yang duplikat: ", duplikat.sum())

# Menghapus data duplikat berdasarkan semua kolom
df = df.drop_duplicates()

print("Jumlah data sebelum dihapus: ", len(df)+duplikat.sum())
print("Jumlah data setelah dihapus: ", len(df))
# Out:
# Jumlah data yang duplikat:  0
# Jumlah data sebelum dihapus:  151
# Jumlah data setelah dihapus:  151

# %%
df.dtypes
# Out:
# tanggal      object
# stasiun      object
# pm10         object
# so2          object
# co           object
# o3           object
# no2          object
# max         float64
# critical     object
# categori     object
# dtype: object

# %%
cat_cols=['critical','categori']
num_cols=['pm10','so2','o3','co', 'no2','max']
string_cols =['stasiun']
date_cols=['tanggal']

#ubah tipe data kolom kategorikal menjadi kategori
for c_col in cat_cols:
    df[c_col] = df[c_col].astype('category')
#ubah tipe data kolom numerikal menjadi float
for n_col in num_cols:
    df[n_col] = df[n_col].astype('float')

for s_col in string_cols:
    df[s_col] = df[s_col].astype('string')

#periksa tipe data semua kolom
print(df.dtypes)
# Out:
# tanggal       object
# stasiun       string
# pm10         float64
# so2          float64
# co           float64
# o3           float64
# no2          float64
# max          float64
# critical    category
# categori    category
# dtype: object

# %% [markdown]
# ### memisahkan jenis data

# %%
# melihat korelasi sebelum dianalisis

import matplotlib.pyplot as plt
import seaborn as sns

# melihat korelasi antara variabel pada dataset menggunakan metode Pearson correlation
corr_matrix = df.corr(method='pearson')
print(corr_matrix)

# membuat heatmap korelasi
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Heatmap Korelasi Pearson")
plt.show()
# Out:
#           pm10       so2        co        o3       no2       max
# pm10  1.000000  0.067537  0.388764  0.090819  0.422337  0.126863
# so2   0.067537  1.000000  0.510356 -0.191389 -0.081680 -0.177302
# co    0.388764  0.510356  1.000000 -0.070448  0.304582 -0.035413
# o3    0.090819 -0.191389 -0.070448  1.000000  0.204056  0.992324
# no2   0.422337 -0.081680  0.304582  0.204056  1.000000  0.209815
# max   0.126863 -0.177302 -0.035413  0.992324  0.209815  1.000000

# %%
# Pisahkan kolom numerik dan kategorik
df_num = df[num_cols]
df_cat = df[cat_cols]
df_date = df[date_cols]
df_string = df[string_cols]

# %%
df_num
# Out:
#      pm10   so2     o3    co   no2    max
# 124  35.0  13.0   46.0  18.0   NaN   46.0
# 125  22.0  15.0  102.0  24.0   7.0  102.0
# 126  44.0  17.0   63.0  21.0   7.0   63.0
# 127  40.0  18.0   85.0  19.0   9.0   85.0
# 128  37.0  21.0   62.0  18.0   5.0   62.0
# ..    ...   ...    ...   ...   ...    ...
# 145  71.0  14.0   97.0  23.0  13.0   97.0
# 146  55.0  14.0   64.0  11.0   7.0   64.0
# 147  58.0  16.0   71.0  10.0   7.0   71.0
# 148  56.0  15.0   90.0  10.0  11.0   90.0
# 149  67.0  15.0   86.0  16.0  10.0   86.0
#
# [151 rows x 6 columns]

# %%
df_cat
# Out:
#     critical     categori
# 124       O3         BAIK
# 125       O3  TIDAK SEHAT
# 126       O3       SEDANG
# 127       O3       SEDANG
# 128       O3       SEDANG
# ..       ...          ...
# 145       O3       SEDANG
# 146       O3       SEDANG
# 147       O3       SEDANG
# 148       O3       SEDANG
# 149       O3       SEDANG
#
# [151 rows x 2 columns]

# %% [markdown]
# ### melihat dan mengatasi missing value

# %%
df.isna().sum()
# Out:
# tanggal      0
# stasiun      0
# pm10         1
# so2         15
# co           1
# o3           0
# no2          7
# max          0
# critical     0
# categori     0
# dtype: int64

# %%
df_num.isna().sum()
# Out:
# pm10     1
# so2     15
# o3       0
# co       1
# no2      7
# max      0
# dtype: int64

# %% [markdown]
# dikarenakan missing value berada pada data numerik, maka kita lihat distribusi datanya apakah berdistribusi normal atau tidak, apabila berdistribusi normal maka akan diatasi dengan nilai median dan apabila tidak berdistribusi normal maka diatasi dengan nilai mean

# %%
from scipy.stats import kstest, norm

def check_normality(df_num, alpha=0.05):
    for col in df_num.columns:
        # ambil kolom
        data = df_num[col]

        # lakukan Kolmogorov Test
        ks_statistic, p_value = kstest(data, cdf='norm')

        # bandingkan p-value dengan alpha level
        if p_value < alpha:
            print(col, "tidak berdistribusi normal")
        else:
            print(col, "berdistribusi normal")
            
check_normality(df_num, alpha=0.05)
# Out:
# pm10 berdistribusi normal
# so2 berdistribusi normal
# o3 tidak berdistribusi normal
# co berdistribusi normal
# no2 berdistribusi normal
# max tidak berdistribusi normal

# %%
# Menentukan kolom numerik yang berdistribusi normal dan tidak normal
num_non_normal = ['o3','max']
num_normal = ['pm10','so2','co','no2']

# Mengisi missing value pada kolom numerik tidak normal dengan mean
for col in num_non_normal:
    df_num[col].fillna(df[col].mean(), inplace=True)

# Mengisi missing value pada kolom numerik normal dengan median
for col in num_normal:
    df_num[col].fillna(df[col].median(), inplace=True)

# Menampilkan hasil
print(df_num)
# Out:
#      pm10   so2     o3    co   no2    max
# 124  35.0  13.0   46.0  18.0   7.0   46.0
# 125  22.0  15.0  102.0  24.0   7.0  102.0
# 126  44.0  17.0   63.0  21.0   7.0   63.0
# 127  40.0  18.0   85.0  19.0   9.0   85.0
# 128  37.0  21.0   62.0  18.0   5.0   62.0
# ..    ...   ...    ...   ...   ...    ...
# 145  71.0  14.0   97.0  23.0  13.0   97.0
# 146  55.0  14.0   64.0  11.0   7.0   64.0
# 147  58.0  16.0   71.0  10.0   7.0   71.0
# 148  56.0  15.0   90.0  10.0  11.0   90.0
# 149  67.0  15.0   86.0  16.0  10.0   86.0
#
# [151 rows x 6 columns]
# C:\Users\Luqna Aziziyah\AppData\Local\Temp\ipykernel_17132\2771297592.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num[col].fillna(df[col].mean(), inplace=True)
# ...

# %%
import pandas as pd

# mendeteksi missing value
print(df_num.isnull().sum())
# Out:
# pm10    0
# so2     0
# o3      0
# co      0
# no2     0
# max     0
# dtype: int64

# %% [markdown]
# ### Menemukan dan mengatasi outlier

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

cols = ['pm10','so2','o3','co', 'no2','max','critical','categori']

# Membuat box plot
sns.boxplot(data=df[cols], orient='h')
plt.title('Box Plot Outlier data diabetes')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Mendapatkan kolom yang ingin dianalisis
data = df['o3'].values  

# Mendeteksi outlier menggunakan metode IQR
def detect_outliers_iqr(data):
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = []
    for i, value in enumerate(data):
        if value < lower_bound or value > upper_bound:
            outliers.append(i)
    return outliers

outliers = detect_outliers_iqr(data)
print("Outliers:", outliers)

# Visualisasi dalam scatter plot
plt.scatter(range(len(data)), data, color='b', label='Data')
plt.scatter(outliers, [data[i] for i in outliers], color='r', label='Outliers')
plt.xlabel('Index')
plt.ylabel('Data Value o3')
plt.title('Outlier Detection using IQR')
plt.legend()
plt.show()
# Out:
# Outliers: [48, 59, 70, 71, 78, 117, 118]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Mendapatkan kolom yang ingin dianalisis
data = df['max'].values 

# Mendeteksi outlier menggunakan metode IQR
def detect_outliers_iqr(data):
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = []
    for i, value in enumerate(data):
        if value < lower_bound or value > upper_bound:
            outliers.append(i)
    return outliers

outliers = detect_outliers_iqr(data)
print("Outliers:", outliers)

# Visualisasi dalam scatter plot
plt.scatter(range(len(data)), data, color='b', label='Data')
plt.scatter(outliers, [data[i] for i in outliers], color='r', label='Outliers')
plt.xlabel('Index')
plt.ylabel('Data Value Max')
plt.title('Outlier Detection using IQR')
plt.legend()
plt.show()
# Out:
# Outliers: [48, 59, 69, 70, 71, 78, 86, 117, 118]

# %%
import pandas as pd
import numpy as np

def outlier_num(df_num, num_cols):
    # Display summary statistics for the numerical columns before and after Winsorizing
    print("Before Winsorizing:")
    print(df_num.describe())
    print("\nAfter Winsorizing:")
    for col in num_cols:
        q1 = np.percentile(df_num[col], 25)
        q3 = np.percentile(df_num[col], 75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        df_num[col] = np.where(df_num[col] < lower_bound, lower_bound, df_num[col])
        df_num[col] = np.where(df_num[col] > upper_bound, upper_bound, df_num[col])
    print(df_num[num_cols].describe())

outlier_num(df_num, num_cols)
# Out:
# Before Winsorizing:
#              pm10         so2          o3          co         no2         max
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean    45.701987   13.192053   75.834437   17.589404    7.523179   76.907285
# std     13.805697    4.561747   26.387227    9.645221    2.675405   25.293834
# min      5.000000    5.000000   30.000000    5.000000    2.000000   33.000000
# 25%     36.000000    9.500000   57.500000   10.000000    6.000000   60.000000
# 50%     48.000000   13.000000   73.000000   15.000000    7.000000   73.000000
# 75%     56.000000   16.000000   88.000000   22.000000    9.000000   88.000000
# max     76.000000   30.000000  182.000000   55.000000   17.000000  182.000000
#
# After Winsorizing:
#              pm10         so2          o3          co         no2         max
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# ...

# %% [markdown]
# ### menggabungkan data

# %%
numerik = df_num.copy()
kategorik = df_cat.copy()
string = df_string.copy()
date = df_date.copy()


data_siap = pd.concat([numerik ,kategorik, string, date],axis=1)
data_siap
# Out:
#      pm10   so2     o3    co   no2    max critical     categori  \
# 124  35.0  13.0   46.0  18.0   7.0   46.0       O3         BAIK
# 125  22.0  15.0  102.0  24.0   7.0  102.0       O3  TIDAK SEHAT
# 126  44.0  17.0   63.0  21.0   7.0   63.0       O3       SEDANG
# 127  40.0  18.0   85.0  19.0   9.0   85.0       O3       SEDANG
# 128  37.0  21.0   62.0  18.0   5.0   62.0       O3       SEDANG
# ..    ...   ...    ...   ...   ...    ...      ...          ...
# 145  71.0  14.0   97.0  23.0  13.0   97.0       O3       SEDANG
# 146  55.0  14.0   64.0  11.0   7.0   64.0       O3       SEDANG
# 147  58.0  16.0   71.0  10.0   7.0   71.0       O3       SEDANG
# 148  56.0  15.0   90.0  10.0  11.0   90.0       O3       SEDANG
# 149  67.0  15.0   86.0  16.0  10.0   86.0       O3       SEDANG
#
#                               stasiun     tanggal
# 124  DKI5 (Kebon Jeruk) Jakarta Barat  2020-01-01
# 125  DKI5 (Kebon Jeruk) Jakarta Barat  2020-01-02
# ...

# %%
data_baru=data_siap.drop(['stasiun', 'tanggal'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# Perform Label Encoding
label_encoder = LabelEncoder()
data_baru['kategori_baru'] = label_encoder.fit_transform(data_baru['categori'])


# Perform Label Encoding
label_encoder = LabelEncoder()
data_baru['critical_baru'] = label_encoder.fit_transform(data_baru['critical'])

data=data_baru.drop(['critical','categori'],axis=1)

# Print the encoded dataframe
print(data)
# Out:
#      pm10   so2     o3    co   no2    max  kategori_baru  critical_baru
# 124  35.0  13.0   46.0  18.0   7.0   46.0              0              0
# 125  22.0  15.0  102.0  24.0   7.0  102.0              2              0
# 126  44.0  17.0   63.0  21.0   7.0   63.0              1              0
# 127  40.0  18.0   85.0  19.0   9.0   85.0              1              0
# 128  37.0  21.0   62.0  18.0   5.0   62.0              1              0
# ..    ...   ...    ...   ...   ...    ...            ...            ...
# 145  71.0  14.0   97.0  23.0  13.0   97.0              1              0
# 146  55.0  14.0   64.0  11.0   7.0   64.0              1              0
# 147  58.0  16.0   71.0  10.0   7.0   71.0              1              0
# 148  56.0  15.0   90.0  10.0  11.0   90.0              1              0
# 149  67.0  15.0   86.0  16.0  10.0   86.0              1              0
#
# [151 rows x 8 columns]

# %%
data_new=data.drop(['max','critical_baru'],axis=1)

# %%
def min_max_normalization(data_new, columns):
    data_normalized = data_new.copy()
    for column in columns:
        data_normalized[column] = (data_new[column] - data_new[column].min()) / (data_new[column].max() - data_new[column].min())
        # Bulatkan nilai hasil normalisasi menjadi tiga angka di belakang koma
        data_normalized[column] = data_normalized[column].round(decimals=3)
    return data_normalized

# Contoh penggunaan fungsi hanya pada kolom "kolom_1" dan "kolom_2"
columns_to_normalize = ["pm10", "so2","o3","co","no2"]
data_normalized = min_max_normalization(data_new, columns_to_normalize)

data_normalized
# Out:
#       pm10    so2     o3     co    no2  kategori_baru
# 124  0.414  0.386  0.154  0.371  0.435              0
# 125  0.229  0.482  0.694  0.543  0.435              2
# 126  0.543  0.578  0.318  0.457  0.435              1
# 127  0.486  0.627  0.530  0.400  0.609              1
# 128  0.443  0.771  0.308  0.371  0.261              1
# ..     ...    ...    ...    ...    ...            ...
# 145  0.929  0.434  0.646  0.514  0.957              1
# 146  0.700  0.434  0.328  0.171  0.435              1
# 147  0.743  0.530  0.395  0.143  0.435              1
# 148  0.714  0.482  0.578  0.143  0.783              1
# 149  0.871  0.482  0.540  0.314  0.696              1
#
# [151 rows x 6 columns]

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# Split the dataset into features and target variable
X = data_normalized.drop('kategori_baru', axis=1)
y = data_normalized['kategori_baru']

# Create a logistic regression model
model = LogisticRegression()

# Create the RFE object and specify the number of features to select (k)
rfe = RFE(estimator=model, n_features_to_select=1)

# Fit the RFE model to the data
rfe.fit(X, y)

# Print the ranking of the features
feature_ranking = pd.DataFrame({'Feature': X.columns, 'Ranking': rfe.ranking_})
feature_ranking = feature_ranking.sort_values(by='Ranking')
print(feature_ranking)
# Out:
#   Feature  Ranking
# 2      o3        1
# 0    pm10        2
# 4     no2        3
# 1     so2        4
# 3      co        5

# %% [markdown]
# # 3. Modeling

# %%
import pandas as pd

# Deklarasikan X dan y
x = data_normalized.drop("kategori_baru", axis=1)  # Menghapus kolom "kategori_baru" dari atribut-atribut
y = data_normalized["kategori_baru"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ## knn

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_train)


x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier (n_neighbors=4)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_pred = knn.predict (x_test)
# Out:
# C:\Users\Luqna Aziziyah\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60         5
#            1       0.88      0.91      0.89        23
#            2       1.00      0.67      0.80         3
#
#     accuracy                           0.84        31
#    macro avg       0.83      0.73      0.76        31
# weighted avg       0.84      0.84      0.84        31

# %%
from sklearn.metrics import accuracy_score

# Prediksi pada data pelatihan
y_pred_train = knn.predict(x_train)
accuracy_train = accuracy_score(y_train, y_pred_train)

# Prediksi pada data testing
y_pred_test = knn.predict(x_test)
accuracy_test = accuracy_score(y_test, y_pred_test)

# Persentase performa pada data pelatihan dan data testing
percentage_train = accuracy_train * 100
percentage_test = accuracy_test * 100

print("Performa pada data pelatihan:", percentage_train, "%")
print("Performa pada data testing:", percentage_test, "%")
# Out:
# Performa pada data pelatihan: 89.16666666666667 %
# Performa pada data testing: 83.87096774193549 %
# C:\Users\Luqna Aziziyah\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# Inisialisasi objek KFold dengan jumlah lipatan yang diinginkan
kf = KFold(n_splits=5)

# Hitung validasi silang menggunakan cross_val_score
scores = cross_val_score(knn, X, y, cv=kf, scoring='accuracy')

# Cetak nilai akurasi untuk setiap lipatan
for fold, score in enumerate(scores):
    print(f"Fold-{fold+1}: {score}")

# Cetak rata-rata akurasi
print("Rata-rata Akurasi: ", scores.mean())
# Out:
# C:\Users\Luqna Aziziyah\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# Fold-1: 0.7741935483870968
# Fold-2: 0.7
# Fold-3: 0.8333333333333334
# Fold-4: 0.9
# Fold-5: 0.9666666666666667
# Rata-rata Akurasi:  0.8348387096774192
# ...

# %% [markdown]
# ## NN

# %%
from sklearn.neural_network import MLPClassifier

nn = MLPClassifier(hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=200)
nn.fit(x_train, y_train)
# Out:
# C:\Users\Luqna Aziziyah\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=3, learning_rate_init=0.1)

# %%
y_pred=nn.predict(x_test)

# %%
# Menghitung precision, recall, dan f1-score
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       0.92      1.00      0.96        23
#            2       1.00      1.00      1.00         3
#
#     accuracy                           0.94        31
#    macro avg       0.97      0.87      0.90        31
# weighted avg       0.94      0.94      0.93        31

# %%
from sklearn.metrics import accuracy_score

# Prediksi pada data pelatihan
y_pred_train = nn.predict(x_train)
accuracy_train = accuracy_score(y_train, y_pred_train)

# Prediksi pada data testing
y_pred_test = nn.predict(x_test)
accuracy_test = accuracy_score(y_test, y_pred_test)

# Persentase performa pada data pelatihan dan data testing
percentage_train = accuracy_train * 100
percentage_test = accuracy_test * 100

print("Performa pada data pelatihan:", percentage_train, "%")
print("Performa pada data testing:", percentage_test, "%")
# Out:
# Performa pada data pelatihan: 95.0 %
# Performa pada data testing: 93.54838709677419 %

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# Inisialisasi objek KFold dengan jumlah lipatan yang diinginkan
kf = KFold(n_splits=5)

# Hitung validasi silang menggunakan cross_val_score
scores = cross_val_score(nn, x, y, cv=kf, scoring='accuracy')

# Cetak nilai akurasi untuk setiap lipatan
for fold, score in enumerate(scores):
    print(f"Fold-{fold+1}: {score}")

# Cetak rata-rata akurasi
print("Rata-rata Akurasi: ", scores.mean())
# Out:
# C:\Users\Luqna Aziziyah\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Luqna Aziziyah\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold-1: 0.8709677419354839
# Fold-2: 0.8
# Fold-3: 0.9
# Fold-4: 0.9666666666666667
# Fold-5: 0.9333333333333333
# Rata-rata Akurasi:  0.8941935483870967
# C:\Users\Luqna Aziziyah\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
